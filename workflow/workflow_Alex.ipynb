# %%
import pandas as pd
import numpy as np

# %%
ecb = pd.read_csv('../inputs/ecb_data.csv', index_col=0)
fed = pd.read_csv('../inputs/fed_data.csv', index_col=0)
series = pd.read_csv('../inputs/train_series.csv', index_col=0)

# %%
ecb
# Out:
#                                                   title  \
# 0     Comments by Yves Mersch at Financial Services ...
# 1     Securing sustained economic growth in the euro...
# 2     The role of monetary policy in addressing the ...
# 3     The pandemic emergency: the three challenges f...
# 4     Transmission channels of monetary policy in th...
# ...                                                 ...
# 1767  Navigating uncertainty - governance, risk mana...
# 1768                            3-6-3: Banks and change
# 1769         Europe's pursuit of ‘a more perfect Union'
# 1770  Monetary policy in the euro area - a brief ass...
# 1771  The ECB and its role as lender of last resort ...
#
#                     speaker                                               text
# 0               Yves Mersch    Comments by Yves Mersch at Financial Service...
# 1          Vítor Constâncio    Securing sustained economic growth in the eu...
# ...

# %%
fed
# Out:
#                                                  title  \
# 0    The Importance of Economic Education and Finan...
# 1         Financial Innovation and Consumer Protection
# 2           Implementing Basel II in the United States
# 3                    An Assessment of the U.S. Economy
# 4        Monetary Policy since the Onset of the Crisis
# ..                                                 ...
# 734  Innovation, Information, and Regulation in Fin...
# 735          Risk Management in Financial Institutions
# 736  Changed Circumstances: The Impact of the Finan...
# 737                                  Welcoming Remarks
# 738         Liquidity Provision by the Federal Reserve
#
#                                           speaker  \
# 0                    Governor Frederic S. Mishkin
# 1                        Chairman Ben S. Bernanke
# 2                    Governor Randall S. Kroszner
# 3    Vice Chair for Supervision Randal K. Quarles
# ...

# %%
series
# Out:
#          Index Name  Index - 9  Index - 8  Index - 7  Index - 6  Index - 5  \
# 0         V2X Index   0.001045   0.005841   0.003832  -0.027519  -0.103565
# 1        MOVE Index  -0.021497   0.007891  -0.013175  -0.008436   0.000000
# 2         SPX Index  -0.001872  -0.008154   0.023588   0.004086   0.003493
# 3         SPX Index   0.004980  -0.000864   0.001677   0.000000   0.006030
# 4     EURUSD Curncy   0.000360  -0.001893   0.005579  -0.003056  -0.001171
# ...             ...        ...        ...        ...        ...        ...
# 8941      SPX Index  -0.002045  -0.003642   0.008096   0.004949  -0.001264
# 8942     SX5E Index  -0.027361   0.094386   0.002350  -0.005076   0.022555
# 8943     SX5E Index  -0.008359   0.021658  -0.015986  -0.023528   0.020072
# 8944    SRVIX Index   0.011945   0.002567   0.000000   0.005115   0.000364
# 8945  EURUSD Curncy  -0.001393  -0.001085   0.002864   0.001853  -0.002394
#
# ...

# %%
print(len(series['Index Name'].unique()))
series['Index Name'].unique()
# Out:
# 9
# array(['V2X Index', 'MOVE Index', 'SPX Index', 'EURUSD Curncy',
#        'EURUSDV1M Curncy', 'CVIX Index', 'VIX Index', 'SX5E Index',
#        'SRVIX Index'], dtype=object)

# %%
series[series['Index Name'] == 'V2X Index']
# Out:
#      Index Name  Index - 9  Index - 8  Index - 7  Index - 6  Index - 5  \
# 0     V2X Index   0.001045   0.005841   0.003832  -0.027519  -0.103565
# 11    V2X Index  -0.035787   0.104474  -0.028211  -0.074643  -0.039099
# 20    V2X Index   0.022172   0.088830   0.049455  -0.078292  -0.065107
# 22    V2X Index   0.009448  -0.094203   0.083527   0.099826   0.005094
# 23    V2X Index  -0.058124  -0.046877  -0.001162  -0.001315   0.018090
# ...         ...        ...        ...        ...        ...        ...
# 8921  V2X Index   0.107613   0.080254   0.119479  -0.019587  -0.089864
# 8922  V2X Index   0.036843  -0.067023  -0.021908  -0.036491  -0.142792
# 8927  V2X Index  -0.050264  -0.052118  -0.060318   0.096750   0.016706
# 8933  V2X Index  -0.060792   0.048623   0.149260  -0.010543   0.000000
# 8937  V2X Index   0.048623   0.149260  -0.010543   0.000000   0.000000
#
#       Index - 4  Index - 3  Index - 2  Index - 1  Index - 0  index ecb  \
# ...

# %%
# Out:
#          Index Name  Index - 9
# 0         V2X Index   0.001045
# 1        MOVE Index  -0.021497
# 2         SPX Index  -0.001872
# 3         SPX Index   0.004980
# 4     EURUSD Curncy   0.000360
# ...             ...        ...
# 8941      SPX Index  -0.002045
# 8942     SX5E Index  -0.027361
# 8943     SX5E Index  -0.008359
# 8944    SRVIX Index   0.011945
# 8945  EURUSD Curncy  -0.001393
#
# [8946 rows x 2 columns]
